# %% [markdown]
# # Plot of model and data

# %% [markdown]
# This notebook plots the synthetic data produced by the simple model and the true model. Also it plots the projection of the initial appoximate.

# %%
import matplotlib as mpb

# show the figures in windows

# show all the matplotlib backends 
#mpb.rcsetup.all_backends 

# force matplotlib to use the 'Qt5Agg' backend 
#mpb.use(arg='Qt5Agg', force=True)

# %%
import cPickle as pickle
import numpy as np

# importing my functions
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
# importing the pickle file of results
resultpath = 'l2-tfa-inversion/multiple-36-l2-reg-54475/'

with open(resultpath+'inversion.pickle') as w:
        inversion = pickle.load(w)

# importing the true model
with open('model.pickle') as w:
        model = pickle.load(w)

# %%
# directory to save the figure and filename
filename = '../../manuscript/figures/thick_model_data.png'

# %% [markdown]
# # Data and model

# %%
mfun.plot_inter_model_data(
    inversion['x'], inversion['y'], inversion['z'],
    inversion['observed_data'], inversion['results'][0][2][0][0],
    model['prisms'], inversion['main_field'][0], inversion['main_field'][1],
    (4.33, 4.33), 1200, [10, 50, 0, 135], [-2.,2.5,-2.5,2.], filename)
