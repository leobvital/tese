# %% [markdown]
# # Plot os Diorama L2-norm solution

# %% [markdown]
# This notebook plots the validation test for multiple inversions and the solution which produces the smallest goal function value for the L2-norm code.

# %%
import numpy as np
import matplotlib as mpb
import cPickle as pickle

# show the figures in windows

# show all the matplotlib backends 
#mpb.rcsetup.all_backends

# force matplotlib to use the 'Qt5Agg' backend 
#mpb.use(arg='Qt5Agg', force=True)

# %%
# importing my functions
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
# importing the pickle file of results
result_path = 'l2-tfa-inversion/multiple-44466-new/'

with open(result_path+'inversion.pickle') as w:
        inversion = pickle.load(w)

# %%
# directory to save the figures
filename = '../../manuscript/figures/diorama-l2-solution.png'
#filename = ''

# %%
z0 = inversion['z0']
intensity = inversion['intensity']
z0_plot, int_plot = np.meshgrid(z0, intensity)
z0_plot = z0_plot.ravel()
int_plot = int_plot.ravel()
n = z0.size
m = intensity.size
N = inversion['x'].size

# %%
# building the matrix of the goal function
gamma_matrix = mfun.goal_matrix(n, m, inversion['results'])

# %%
np.min(gamma_matrix)
# Out:
# 22649.80079802965

# %%
np.argmin(gamma_matrix)
# Out:
# 47

# %%
# parameters for the figure
vmin = int(np.min(gamma_matrix))
vmax = 50000.
solutions = [[4,7]]
norm = 2
figsize = (4.33, 4.33)
inset_position = (0.35, 0.95)
dpi = 1200
angles= [15, 40, 10,115]
area = [8210, 8215, 475, 480]

# %% [markdown]
# # Figures

# %%
mfun.plot_diorama_solution(
    inversion['x'], inversion['y'],
    inversion['z'], inversion['results'][47][3],
    inversion['results'][47][2][-1],
    inversion['results'][47][2][0],
    z0, intensity, gamma_matrix, vmin,
    vmax, solutions, norm, figsize,
    inset_position, dpi,
    angles, area, filename
)
