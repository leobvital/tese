# %% [markdown]
# # Regional separation

# %% [markdown]
# ### Importing packages

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from fatiando.vis import mpl
import pandas as pd
import matplotlib as mpb
import cPickle as pickle
import matplotlib.patches as patches
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %% [markdown]
# ### Observation points and observed data

# %%
with open('data.pickle') as w:
        data = pickle.load(w)

# %%
dobs = data['tfa_obs']
xp = data['x']
yp = data['y']
zp = data['z']
N = data['N']

# %%
xp
# Out:
# array([ 8981.07703745,  8868.07703745,  8757.07703745, ...,
#        15702.07703745, 15806.07703745, 15911.07703745])

# %% [markdown]
# ### Data plot

# %%
plt.figure(figsize=(6,5))

plt.subplot(1,1,1)
plt.title("Total-field anomaly (nT)")
#plt.axis('scaled')
norm=mpb.colors.Normalize(vmin=-np.max(dobs), vmax=np.max(dobs))
plt.tricontourf(yp, xp, dobs, 30, cmap ='RdBu_r', norm=norm)
plt.colorbar()
#plt.plot(yp, xp, 'ok', markersize=0.5)
plt.xlabel('y (km)')
plt.ylabel('x (km)')
#mpl.m2km()

plt.tight_layout(pad = 2.)

plt.show()

# %% [markdown]
# ### Simple polynomial fitting

# %%
A = np.vstack((np.ones(N), xp, yp)).T

# %%
ATA = np.dot(A.T,A)
t = np.trace(ATA)/N
mu = 0.00000001*t

# %%
p1 = np.linalg.solve(ATA + mu*np.identity(3),np.dot(A.T,dobs))

# %%
tfa_regional1 = np.dot(A,p1)

# %%
tfa_residual1 = dobs - tfa_regional1

# %%
#plt.close('all')
plt.figure(figsize=(12,10))

# Create a Rectangle patch
rect = patches.Rectangle((-5000.,-5000.0), 10000,10000,linewidth=1,edgecolor='m',facecolor='none')

ax1=plt.subplot(2,2,1)
#plt.title("Observed data (nT)")
norm=mpb.colors.Normalize(vmin=-np.max(dobs), vmax=np.max(dobs))
#plt.axis('scaled')
plt.tricontour(yp, xp, dobs, 20, colors='k', linewidths=0.5)
plt.tricontourf(yp, xp, dobs, 20, cmap = plt.get_cmap('RdBu_r'), vmin=-np.max(dobs), vmax=np.max(dobs))
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT', pad=-295, fontsize=10)
plt.xlabel('y (km)')
plt.ylabel('x (km)')
ax1.add_patch(rect)
plt.text(np.min(yp)-1000, np.max(xp)+1000, '(a)', fontsize=20)
mpl.m2km()

ax4=plt.subplot(2,2,4)
rect = patches.Rectangle((-5000.,-5000.0), 10000,10000,linewidth=1,edgecolor='m',facecolor='none')
#plt.title("Estimanted regional data (nT)")
#plt.axis('scaled')
#norm=mpb.colors.Normalize(vmin=-np.max(tfa_regional1), vmax=np.max(tfa_regional1))
plt.tricontourf(yp, xp, tfa_regional1, 15, cmap = plt.get_cmap('RdBu_r'),
               vmin=np.min(tfa_regional1), vmax=np.max(tfa_regional1))
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT', pad=-295, fontsize=10)
plt.xlabel('y (km)')
plt.ylabel('x (km)')
ax4.add_patch(rect)
plt.text(np.min(yp)-1000, np.max(xp)+1000, '(d)', fontsize=20)
mpl.m2km()

ax3=plt.subplot(2,2,3)
rect = patches.Rectangle((-5000.,-5000.0), 10000,10000,linewidth=1,edgecolor='m',facecolor='none')
#plt.title("Residual data (nT)")
#plt.axis('scaled')
plt.tricontour(yp, xp, tfa_residual1, 20, colors='k', linewidths=0.5)
norm=mpb.colors.Normalize(vmin=np.min(tfa_residual1), vmax=-np.min(tfa_residual1))
plt.tricontourf(yp, xp, tfa_residual1, 20, cmap = plt.get_cmap('RdBu_r'), norm=norm)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT', pad=-295, fontsize=10)
plt.xlabel('y (km)')
plt.ylabel('x (km)')
ax3.add_patch(rect)
plt.text(np.min(yp)-1000, np.max(xp)+1000, '(c)', fontsize=20)
mpl.m2km()

ax2=plt.subplot(2,2,2)
rect = patches.Rectangle((-5000.,-5000.0), 10000,10000,linewidth=1,edgecolor='m',facecolor='none')
#plt.title("True regional data (nT)")
#plt.axis('scaled')
#norm=mpb.colors.Normalize(vmin=-np.max(data['regional']), vmax=np.max(data['regional']))
plt.tricontourf(yp, xp, data['regional'], 15, cmap = plt.get_cmap('RdBu_r'),
               vmin=np.min(data['regional']), vmax=np.max(data['regional']))
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT', pad=-295, fontsize=10)
plt.xlabel('y (km)')
plt.ylabel('x (km)')
ax2.add_patch(rect)
plt.text(np.min(yp)-1000, np.max(xp)+1000, '(b)', fontsize=20)
mpl.m2km()

# Add the patch to the Axes


plt.tight_layout(pad = 2.)

plt.savefig('../../manuscript/Figs/inclined-data-large.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
data['res_data'] = tfa_residual1

# %%
data['est_regional'] = tfa_regional1

# %%
d = {'x': xp, 'y': yp, 'z': zp, 'tfa_true': data['tfa'], 'dobs': data['tfa_obs'], 'res_data': tfa_residual1, 'regional': tfa_regional1}

# %%
dataset = pd.DataFrame(d)

# %%
mask = (dataset['y'] <= 5000.) & (dataset['y'] >= -5000.) & (dataset['x'] <= 5000.) & (dataset['x'] >= -5000.)
d2 = dataset[mask]
d2.reset_index(inplace=True)

# %% [raw]
# dataset.to_csv('anitapolis_large_decimated_tfa_residual.txt', sep=' ')

# %%
np.min(d2['y'])
# Out:
# -4645.405631446862

# %% [raw]
# #plt.close('all')
# plt.figure(figsize=(12,10))
#
# plt.subplot(2,2,1)
# #plt.title("Observed data (nT)")
# norm=mpb.colors.Normalize(vmax=np.max(d2['dobs']), vmin=-np.max(d2['dobs']))
# plt.tricontour(d2['y'], d2['x'], d2['dobs'], 20, colors='k', linewidths=0.5)
# plt.tricontourf(d2['y'], d2['x'], d2['dobs'], 20, cmap ='RdBu_r', norm=norm)
# plt.plot(d2['y'], d2['x'], '.k', markersize=0.2)
# plt.colorbar()
# plt.xlabel('y (km)')
# plt.ylabel('x (km)')
# mpl.m2km()
#
# plt.subplot(2,2,2)
# #plt.title("Regional data (nT)")
# #plt.axis('scaled')
# plt.tricontourf(d2['y'], d2['x'],d2['regional'], 15, cmap = plt.get_cmap('RdBu_r'))
# plt.plot(d2['y'], d2['x'], '.k', markersize=0.2)
# plt.colorbar()
# plt.xlabel('y (km)')
# plt.ylabel('x (km)')
# mpl.m2km()
#
# plt.subplot(2,2,1)
# #plt.title("Residual data (nT)")
# plt.tricontour(d2['y'], d2['x'], d2['res_data'], 20, colors='k', linewidths=0.5)
# norm=mpb.colors.Normalize(vmin=np.min(d2['res_data']), vmax=-np.min(d2['res_data']))
# plt.tricontourf(d2['y'], d2['x'], d2['res_data'], 20, cmap = plt.get_cmap('RdBu_r'), norm=norm)
# plt.plot(d2['y'], d2['x'], '.k', markersize=0.2)
# plt.colorbar()
# plt.xlabel('y (km)')
# plt.ylabel('x (km)')
# mpl.m2km()
#
# plt.subplot(2,2,4)
# #plt.title("Campo esfera (nT)")
# #plt.axis('scaled')
# plt.tricontourf(d2['y'], d2['x'], d2['dobs']-d2['res_data'], 15, cmap = plt.get_cmap('RdBu_r'))
# plt.plot(d2['y'], d2['x'], '.k', markersize=0.2)
# plt.colorbar()
# plt.xlabel('y (km)')
# plt.ylabel('x (km)')
# mpl.m2km()
#
# plt.tight_layout(pad = 2.)
#
#
# plt.savefig('../../manuscript/Figs/inclined-data-cut.png', dpi=300, bbox_inches='tight')
#
# plt.show()

# %%
d2.to_csv('inclined_model_data.txt', sep=' ')
