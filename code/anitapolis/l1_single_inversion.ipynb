# %% [markdown]
# # Anitapolis single L1 TFA Inversion

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA) data of Anitápolis.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import pandas as pd
import os

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.vis import mpl
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
from datetime import datetime
today = datetime.today()
# dd/mm/YY/Hh/Mm
d4 = today.strftime("%d-%b-%Y-%Hh:%Mm")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing Anitapolis TFA data

# %%
data = pd.read_csv('anitapolis_decimated_tfa_residual_cut.txt', skipinitialspace=True, delim_whitespace=True)

# %%
data['GPSALT'] = - data['GPSALT'] + 800

# %%
mask = (data['GPSALT'].get_values()<0.)
data = data[mask]

# %%
xp = data['X'].get_values()
yp = data['Y'].get_values()
zp = data['GPSALT'].get_values()
alt = data['ALTURA'].get_values()
dobs = data['mag_res1'].get_values()

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 20 # number of vertices per prism
L = 6 # number of prisms
P = L*(M+2) + 1 # number of parameters

# depth to the top, thickness, origin, magnetization and radius
incs = -21
decs = -11
intensity = 17
z0 = 200
dz = 900.
r = 800.
x0 = 6921000.
y0 = 688000.

# main field
inc, dec = [-37.05, -18.17]

model0, m0 = mfun.initial_cylinder(M, L, x0,
        y0, z0, dz, r, inc, dec, incs, decs, intensity)

# predict data
d0 = polyprism.tf(xp, yp, zp, model0, inc, dec)

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.title('Observed TFA', fontsize=20)
plt.tricontourf(yp, xp, dobs, 20, cmap='RdBu_r').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
estimate = mpl.polygon(model0[0], '.-y', xy2ne=True)
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)

plt.subplot(122)
plt.title('Predicted TFA', fontsize=20)
plt.tricontourf(yp, xp, d0, 20, cmap='RdBu_r').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
estimate = mpl.polygon(model0[0], '.-y', xy2ne=True)
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)

plt.show()

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)
#m_out = model['param_vec'][:M+2]

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 10.
rmax = 1200.
y0min = 687000.
y0max = 699000.
x0min = 6916000.
x0max = 6923000.
dzmin = 10.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Derivatives

# %%
# variation for derivatives
deltax = 0.01*np.max(100.)
deltay = 0.01*np.max(100.)
deltar = 0.01*np.max(100.)
deltaz = 0.01*np.max(100.)

delta = np.array([deltax, deltay, deltar, deltaz])

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 10.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 1.0e-3  # adjacent radial distances within each prism
a2 = 1.0e-3   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 1.0e-3    # vertically adjacent origins
a6 = 1.0e-6   # zero order Tikhonov on adjacent radial distances
a7 = 1.0e-5     # zero order Tikhonov on thickness of each prism

alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Folder to save the results

# %%
foldername = ''

# %%
if foldername == '':
    mypath = 'l1-tfa-inversion/single-'+d4 #default folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)
else:
    mypath = 'l1_tfa_inversion/single-'+foldername #defined folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)

# %% [markdown]
# ### Iterations and stop criterion

# %%
itmax = 30       # maximum iteration
itmax_marq = 10  # maximum iteration of Marquardt's loop
tol = 1.0e-4     # stop criterion

# %% [markdown]
# ### Inversion

# %%
d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.l1_levmarq_tf(
    xp, yp, zp, m0, M, L, delta,
    itmax, itmax_marq, lamb,
    dlamb, tol, mmin, mmax,
    m_out, dobs, inc, dec,
    model0[0].props, alpha, z0, dz
)
# Out:
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 9.17519e+01  fin obj.: 6.70648e+01
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 6.70648e+01  fin obj.: 4.58302e+01
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 4.58302e+01  fin obj.: 3.20883e+01
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 3.20883e+01  fin obj.: 3.79564e+01
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 3.20883e+01  fin obj.: 2.82923e+01
# it:  4   it_marq:  0   lambda: 1e-02   init obj.: 2.82923e+01  fin obj.: 4.33121e+01
# it:  4   it_marq:  1   lambda: 1e-01   init obj.: 2.82923e+01  fin obj.: 4.46790e+01
# it:  4   it_marq:  2   lambda: 1e+00   init obj.: 2.82923e+01  fin obj.: 3.49209e+01
# it:  4   it_marq:  3   lambda: 1e+01   init obj.: 2.82923e+01  fin obj.: 2.73316e+01
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 2.73316e+01  fin obj.: 2.55580e+01
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 2.55580e+01  fin obj.: 4.09774e+01
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 2.55580e+01  fin obj.: 2.39327e+01
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 2.39327e+01  fin obj.: 3.55143e+01
# it:  7   it_marq:  1   lambda: 1e+00   init obj.: 2.39327e+01  fin obj.: 2.47523e+01
# it:  7   it_marq:  2   lambda: 1e+01   init obj.: 2.39327e+01  fin obj.: 2.32037e+01
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 2.32037e+01  fin obj.: 2.33511e+01
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 2.32037e+01  fin obj.: 2.24370e+01
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 2.24370e+01  fin obj.: 2.43242e+01
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 2.24370e+01  fin obj.: 2.30954e+01
# it:  9   it_marq:  2   lambda: 1e+02   init obj.: 2.24370e+01  fin obj.: 2.29362e+01
# it:  9   it_marq:  3   lambda: 1e+03   init obj.: 2.24370e+01  fin obj.: 2.25305e+01
# it:  9   it_marq:  4   lambda: 1e+04   init obj.: 2.24370e+01  fin obj.: 2.25393e+01
# it:  9   it_marq:  5   lambda: 1e+05   init obj.: 2.24370e+01  fin obj.: 2.24371e+01
# it:  9   it_marq:  6   lambda: 1e+06   init obj.: 2.24370e+01  fin obj.: 2.24372e+01
# it:  9   it_marq:  7   lambda: 1e+07   init obj.: 2.24370e+01  fin obj.: 2.24372e+01
# it:  9   it_marq:  8   lambda: 1e+08   init obj.: 2.24370e+01  fin obj.: 2.24372e+01
# it:  9   it_marq:  9   lambda: 1e+09   init obj.: 2.24370e+01  fin obj.: 2.24372e+01

# %% [markdown]
# # Results

# %%
# output of inversion
inversion = dict()

inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['initial_estimate'] = model0
inversion['initial_data'] = d0
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = np.array([a1, a2, a3, a4, a5, a6, a7])
inversion['tol'] = tol
inversion['main_field'] = [-21.5, -18.7]
inversion['data_fit'] = d_fit
inversion['estimate'] = m_est
inversion['prisms'] = model_est
inversion['estimated_models'] = model_list
inversion['objective'] = phi_list
inversion['residual'] = dobs - d_fit
inversion['residual_list'] = res_list

# %% [markdown]
# ### Saving results

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
