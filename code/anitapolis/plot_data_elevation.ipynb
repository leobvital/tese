# %% [markdown]
# # Plot of data and elevation

# %% [markdown]
# This notebook plots the observed data and the elevation of the observations. Also it plots the projection of the initial appoximate.

# %%
import matplotlib as mpb
import cPickle as pickle

# show the figures in windows

# show all the matplotlib backends 
#mpb.rcsetup.all_backends

# force matplotlib to use the 'Qt5Agg' backend 
#mpb.use(arg='Qt5Agg', force=True)

import pandas as pd

# importing my functions
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun
# Out:
# /home/leo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
dataset = pd.read_csv('anitapolis_large_decimated.txt', skipinitialspace=True, delim_whitespace=True)

# %%
# importing the data and elevation
data = pd.read_csv('anitapolis_decimated_tfa_residual_cut.txt', skipinitialspace=True, delim_whitespace=True)

data['GPSALT'] = - data['GPSALT'] + 800

mask = (data['GPSALT'].get_values()<0.)
data = data[mask]

# %%
# importing the pickle file of results
result_path = 'l2-tfa-inversion/multiple-43485/'

with open(result_path+'inversion.pickle') as w:
        inversion = pickle.load(w)

# %%
# directory to save the figure and filename
#filename = '../../manuscript/figures/anitapolis_data.png'
filename = ''

# %%
mfun.plot_obs_alt(
    dataset['X'], dataset['Y'], dataset['MAGIGRF'],
    dataset['GPSALT'], dataset['GPSALT']+dataset['ALTURA'],
    inversion['results'][0][2][0][0], (4.33,4.33), 1200, filename)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-159d0916afd3> in <module>()
#       2     dataset['X'], dataset['Y'], dataset['MAGIGRF'],
#       3     dataset['GPSALT'], dataset['GPSALT']+dataset['ALTURA'],
# ----> 4     inversion['results'][0][2][0][0], (4.33,4.33), 1200, filename)
#
# /home/leo/Documentos/l1-magnetic-radial-inversion/code/mag_polyprism_functions.pyc in plot_obs_alt(x, y, obs, alt, topo, initial, figsize, dpi, filename)
#    2976
#    2977     ax3=plt.subplot(2,2,3)
# -> 2978     plt.tricontourf(y, x, topo, 10, cmap='terrain_r', vmax=300).ax.tick_params(labelsize=6)
#    2979     plt.plot(y, x, 'k.', markersize=.25)
#    2980     plt.xlabel('$y$(km)', fontsize=6)
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in tricontourf(*args, **kwargs)
#    3670                       mplDeprecation)
#    3671     try:
# -> 3672         ret = ax.tricontourf(*args, **kwargs)
#    3673     finally:
#    3674         ax._hold = washold
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in tricontourf(self, *args, **kwargs)
#    8142
#    8143     def tricontourf(self, *args, **kwargs):
# -> 8144         return mtri.tricontourf(self, *args, **kwargs)
#    8145     tricontourf.__doc__ = mtri.tricontour.__doc__
#    8146
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/tri/tricontour.pyc in tricontourf(ax, *args, **kwargs)
#     280         ax.cla()
#     281     kwargs['filled'] = True
# --> 282     return TriContourSet(ax, *args, **kwargs)
#     283 tricontourf.__doc__ = tricontour.__doc__
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/tri/tricontour.pyc in __init__(self, ax, *args, **kwargs)
#      38         are described in the docstring of `tricontour`.
#      39         """
# ---> 40         ContourSet.__init__(self, ax, *args, **kwargs)
#      41
#      42     def _process_args(self, *args, **kwargs):
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     938         if vmax is not None:
#     939             self.norm.vmax = vmax
# --> 940         self._process_colors()
#     941
#     942         self.allsegs, self.allkinds = self._get_allsegs_and_allkinds()
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/contour.pyc in _process_colors(self)
#    1309             self.cvalues = self.layers
#    1310         self.set_array(self.levels)
# -> 1311         self.autoscale_None()
#    1312         if self.extend in ('both', 'max', 'min'):
#    1313             self.norm.clip = False
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/cm.pyc in autoscale_None(self)
#     362             raise TypeError('You must first set_array for mappable')
#     363         self.norm.autoscale_None(self._A)
# --> 364         self.changed()
#     365
#     366     def add_checker(self, checker):
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/contour.pyc in changed(self)
#    1158     def changed(self):
#    1159         tcolors = [(tuple(rgba),)
# -> 1160                    for rgba in self.to_rgba(self.cvalues, alpha=self.alpha)]
#    1161         self.tcolors = tcolors
#    1162         hatches = self.hatches * len(tcolors)
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/cm.pyc in to_rgba(self, x, alpha, bytes, norm)
#     272         x = ma.asarray(x)
#     273         if norm:
# --> 274             x = self.norm(x)
#     275         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     276         return rgba
#
# /home/leo/anaconda2/lib/python2.7/site-packages/matplotlib/colors.pyc in __call__(self, value, clip)
#     945             result.fill(0)   # Or should it be all masked?  Or 0.5?
#     946         elif vmin > vmax:
# --> 947             raise ValueError("minvalue must be less than or equal to maxvalue")
#     948         else:
#     949             if clip:
#
# ValueError: minvalue must be less than or equal to maxvalue
