# %% [markdown]
# # Santa Catarina TFA inversion

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os

from fatiando import utils
from fatiando.vis import mpl
from fatiando.gravmag import polyprism
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing TFA data

# %%
datapath = 'eqlayer_rs/direction_inc-37_dec-18_h-400m/eqlayer_depth-400m.pickle'

# %%
with open(datapath) as w:
        data = pickle.load(w)

# %%
xp = data['x']
yp = data['y']
zp = data['z']
dobs = data['amf']

# %% [markdown]
# ### Parameters for inversion

# %%
# output of inversion
inversion = dict()

# %%
inversion['xp'] = xp
inversion['yp'] = yp
inversion['zp'] = zp
inversion['observed_data'] = dobs
N = xp.size

# %%
#initial estimate
M = 30 # number of vertices per prism
L = 8 # number of prismsinc-37_dec-18_r1000_int6_z0250_dz300/
P = L*(M+2) + 1 # number of parameters

#figura
incs = -37.05
decs = -18.17
intensity = 2.5
z0 = -1200.
dz = 900.
r = 1500.
x0 = 6921000.
y0 = 688000.

# main field
inc = -37.05
dec = -18.17

model0, m0 = mfun.initial_cylinder(M, L, x0,
        y0, z0, dz, r, inc, dec, incs, decs, intensity)

# predict data
d0 = np.sqrt(polyprism.bx(xp, yp, zp, model0)**2.+
            polyprism.by(xp, yp, zp, model0)**2.+
            polyprism.bz(xp, yp, zp, model0)**2.)

# %%
plt.figure(figsize=(6,5))
plt.title('Observed AMF', fontsize=20)
plt.tricontourf(yp, xp, dobs, 20, cmap='RdBu_r').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.title('Predicted AMF', fontsize=20)
plt.tricontourf(yp, xp, d0, 20, cmap='RdBu_r').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)
plt.show()

# %%
# limits for parameters in meters
rmin = 100.
rmax = 3500.
y0min = 684000.
y0max = 693000.
x0min = 6918250.
x0max = 6926250.
dzmin = 10.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %%
# variation for derivatives
deltax = 0.01*np.max(1000.)
deltay = 0.01*np.max(1000.)
deltar = 0.01*np.max(1000.)
deltaz = 0.01*np.max(1000.)
delta = np.array([deltax, deltay, deltar, deltaz])

# %%
m_out = np.zeros(M + 2)  # outcropping body parameters

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 10.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 1.0e-6  # adjacent radial distances within each prism
a2 = 1.0e-6   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 1.0e-6     # vertically adjacent origins
a6 = 1.0e-8   # zero order Tikhonov on adjacent radial distances
a7 = 1.0e-6     # zero order Tikhonov on thickness of each prism

# %%
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %%
itmax = 30
itmax_marq = 10
tol = 1.0e-4     # stop criterion

# %% [markdown]
# ### Inversion

# %%
d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_tf(xp, yp, zp, m0, M, L, delta, itmax,
                                                    itmax_marq, lamb, dlamb, tol,
                                                    mmin, mmax, m_out, dobs, inc, dec,
                                                    model0[0].props, alpha, z0, dz)
# Out:
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.08551e+04  fin obj.: 1.67973e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.67973e+04  fin obj.: 1.30916e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.30916e+04  fin obj.: 2.32150e+04
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 1.30916e+04  fin obj.: 2.15134e+04
# it:  2   it_marq:  2   lambda: 1e+01   init obj.: 1.30916e+04  fin obj.: 1.44223e+04
# it:  2   it_marq:  3   lambda: 1e+02   init obj.: 1.30916e+04  fin obj.: 1.15608e+04
# it:  3   it_marq:  0   lambda: 1e+01   init obj.: 1.15608e+04  fin obj.: 1.79446e+04
# it:  3   it_marq:  1   lambda: 1e+02   init obj.: 1.15608e+04  fin obj.: 1.08878e+04
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.08878e+04  fin obj.: 2.44947e+04
# it:  4   it_marq:  1   lambda: 1e+02   init obj.: 1.08878e+04  fin obj.: 1.07655e+04
# it:  5   it_marq:  0   lambda: 1e+01   init obj.: 1.07655e+04  fin obj.: 2.66687e+04
# it:  5   it_marq:  1   lambda: 1e+02   init obj.: 1.07655e+04  fin obj.: 1.02085e+04
# it:  6   it_marq:  0   lambda: 1e+01   init obj.: 1.02085e+04  fin obj.: 2.68555e+04
# it:  6   it_marq:  1   lambda: 1e+02   init obj.: 1.02085e+04  fin obj.: 9.99133e+03
# it:  7   it_marq:  0   lambda: 1e+01   init obj.: 9.99133e+03  fin obj.: 2.65249e+04
# it:  7   it_marq:  1   lambda: 1e+02   init obj.: 9.99133e+03  fin obj.: 9.70834e+03
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 9.70834e+03  fin obj.: 3.19616e+04
# it:  8   it_marq:  1   lambda: 1e+02   init obj.: 9.70834e+03  fin obj.: 9.29421e+03
# it:  9   it_marq:  0   lambda: 1e+01   init obj.: 9.29421e+03  fin obj.: 2.61277e+04
# it:  9   it_marq:  1   lambda: 1e+02   init obj.: 9.29421e+03  fin obj.: 9.22032e+03
# it: 10   it_marq:  0   lambda: 1e+01   init obj.: 9.22032e+03  fin obj.: 3.18774e+04
# it: 10   it_marq:  1   lambda: 1e+02   init obj.: 9.22032e+03  fin obj.: 1.57624e+04
# it: 10   it_marq:  2   lambda: 1e+03   init obj.: 9.22032e+03  fin obj.: 8.98430e+03
# it: 11   it_marq:  0   lambda: 1e+02   init obj.: 8.98430e+03  fin obj.: 9.08890e+03
# it: 11   it_marq:  1   lambda: 1e+03   init obj.: 8.98430e+03  fin obj.: 9.16489e+03
# it: 11   it_marq:  2   lambda: 1e+04   init obj.: 8.98430e+03  fin obj.: 9.18069e+03
# it: 11   it_marq:  3   lambda: 1e+05   init obj.: 8.98430e+03  fin obj.: 9.67215e+03
# it: 11   it_marq:  4   lambda: 1e+06   init obj.: 8.98430e+03  fin obj.: 9.00800e+03
# it: 11   it_marq:  5   lambda: 1e+07   init obj.: 8.98430e+03  fin obj.: 8.92673e+03
# it: 12   it_marq:  0   lambda: 1e+06   init obj.: 8.92673e+03  fin obj.: 8.92623e+03

# %%
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['initial_estimate'] = model0
inversion['initial_data'] = d0
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = alpha
inversion['tol'] = tol
inversion['main_field'] = [inc, dec]

# %%
mypath = 'amf_inversion/V%d_L%d_inc%d_dec%d_r%d_int%d_z0%d_dz%d' % (M, L, incs, decs, r, intensity, z0, dz)
if not os.path.isdir(mypath):
   os.makedirs(mypath)

# %%
inversion['data_fit'] = d_fit
inversion['estimate'] = m_est
inversion['prisms'] = model_est
inversion['objective'] = phi_list
inversion['residual'] = dobs - d_fit

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
